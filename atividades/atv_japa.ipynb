# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cardapio_japones = {
    "Temaki de Salmão": 22.90,
    "Temaki Califórnia": 20.90,
    "Temaki de Atum": 23.90,
    "Temaki Skin": 19.90,
    "Sashimi de Salmão (10 peças)": 34.90,
    "Sashimi de Atum (10 peças)": 36.90,
    "Sashimi de Peixe Branco": 32.90,
    "Uramaki Califórnia": 24.90,
    "Uramaki Salmão com Cream Cheese": 26.90,
    "Hossomaki de Salmão": 18.90,
    "Hossomaki de Kani Kama": 17.90,
    "Hot Roll (8 peças)": 28.90,
    "Gyoza (6 unidades)": 21.90,
    "Yakisoba de Carne": 29.90,
    "Yakisoba de Frango": 27.90,
    "Missoshiru": 12.90,
    "Edamame": 14.90,
    "Sunomono": 11.90,
    "Donburi (Gyudon)": 33.90,
    "Tempurá de Legumes": 22.90
}


pedidos_registrados = []

def mostrar_cardapio():
    print("Cardápio Japonês:")
    for item, preco in cardapio_japones.items():
        print(f"{item}: R$ {preco:.2f}")

def registrar_pedido():
    numero_mesa = int(input("Digite o número da mesa: "))
    garcom = input("Digite o nome do garçom: ")
    pedidos = []
    while True:
        pedido = input("Digite o nome do pedido (ou pressione Enter para finalizar): ")
        if pedido == "-":
            break
        if pedido not in cardapio_japones:
            print("Pedido não encontrado no cardápio. Tente novamente.")
        continue
    pedidos.append(pedido)
    numero_pedido = len(pedidos_registrados) + 1 # contador para que o número do pedido seja único, começa sem pedidos e vai adicionando 1 a cada novo pedido
    pedido_dict = {
        "numero_pedido": numero_pedido, 
        "mesa": numero_mesa,
        "garcom": garcom,
        "pedidos": pedidos
    }
    pedidos_registrados.append(pedido_dict)
    print("Pedido registrado com sucesso!")

def fecharConta():


    print('\n BEM VINDO AO MENU')
op = int(input(print('\n Escolha uma opção: \n 1- Visualizar cardápio\n 2- Registrar pedido \n 3- Fechar a conta \n  4- Ver pedidos registrados \n 5- Sair \n')))
match op:
    case 1:
        mostrar_cardapio()
        
    case 2:
        registrar_pedido()
        
    case 3:
        fecharConta()

    case 4:
        print(pedidos_registrados)
    
    case _:
        print('')
# Out:
#  Escolha uma opção:
#  1- Visualizar cardápio
#  2- Registrar pedido
#  3- Fechar a conta
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 58
#      54 def fecharConta():
#      57     print('\n BEM VINDO AO MENU')
# ---> 58 op = int(input(print('\n Escolha uma opção: \n 1- Visualizar cardápio\n 2- Registrar pedido \n 3- Fechar a conta \n ')))
#      59 match op:
#      60     case 1:
#
# ValueError: invalid literal for int() with base 10: ''
