# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### acumulo do ano

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### max data para saber os 3 meses anteriores, começa em janeiro e depois soma os 2 anteriores
