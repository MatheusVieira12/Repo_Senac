# %% [markdown]
# ![image.png](attachment:image.png) ### nesse formato dimensão para fato; 1 para muitos, muitos id clientre dentro do caramelo

# %% [markdown]
# ![image.png](attachment:image.png) ### as estrutura como deve ser

# %% [markdown]
# drill up e drill down navegadores de hieraquia
#
#
# soma de todos os dados de todos os anos
# ![image.png](attachment:image.png)
#
#
# mês e seu respectivo ano
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# relatorio = powerBI
#
# dahsboard = painel no workspace
