# %% [markdown]
# ### AULA SQL
# ### CRTL + SHIFT + END PARA SELECIONAR TUDO PARA BAIXO
# ### CRTL + SHIFT + ENTER = RODAR CODIGO
#
# ## o contexto de filtro não precisa aparecer, no caso o nome da coluna da condição
# ![image.png](attachment:image.png)

# %% [markdown]
# ## não existe no banco, apenas consulta
# ![image.png](attachment:image.png)

# %% [markdown]
# ## CONTA QUANTAS VEZES APARECE OS ESTADOS
# ![image.png](attachment:image.png)

# %% [markdown]
# ### o group by é feito pela variavel qualitativa
# ### group by para agrupar a variavel
# ### agregação de valor dos quantitativos feito pelo sum
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ### having após o group by
